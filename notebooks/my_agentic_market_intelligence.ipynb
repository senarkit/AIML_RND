# %% [markdown]
# # Agentic AI for Market Intelligence
#
# ## Understanding Market Trends for a Startup’s Product Idea
#
# This notebook explores how multi-agent AI systems can autonomously gather and analyze market intelligence to help startups evaluate product ideas.
#
# We build AI agents that perform the following tasks:
#
# 1. **Web Scraping** – Using LlamaIndex's simple web crawler to collect market data from relevant sources.
# 2. **Sentiment Analysis** – Analyzing customer sentiment about similar products or industry trends.
# 3. **Competitive Intelligence** – Extracting key insights about competitors, potential gaps, and market trends.
#
# ### Why This Matters for Startups
#
# - **Validate Product-Market Fit:** Identify if the startup’s product idea has demand.
# - **Understand Competitor Positioning:** Learn from existing competitors and their market strategies.
# - **Discover Emerging Trends:** Use AI-driven insights to spot trends that influence product development.
#
# ### Requirements
# Ensure you have the necessary dependencies installed:
# - `llama-index`
# - `beautifulsoup4`
# - `requests`
#
# Let's begin by setting up the required tools and agents.

# %%
# !pip install llama-index beautifulsoup4 requests groq llama-index-llms-groq llama-index-readers-web faiss-cpu
# Out:
# Collecting llama-index
#   Downloading llama_index-0.12.15-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.12.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Collecting groq
#   Downloading groq-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting llama-index-llms-groq
#   Downloading llama_index_llms_groq-0.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting llama-index-readers-web
#   Downloading llama_index_readers_web-0.3.5-py3-none-any.whl.metadata (1.2 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting llama-index-agent-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.3-py3-none-any.whl.metadata (727 bytes)
# Collecting llama-index-cli<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_cli-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.13.0,>=0.12.15 (from llama-index)
#   Downloading llama_index_core-0.12.15-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-embeddings-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.6.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-llms-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.3.15-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-file<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_file-0.4.4-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Collecting llama-index-llms-openai-like<0.4.0,>=0.3.1 (from llama-index-llms-groq)
#   Downloading llama_index_llms_openai_like-0.3.3-py3-none-any.whl.metadata (751 bytes)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-web) (3.11.11)
# Collecting chromedriver-autoinstaller<0.7.0,>=0.6.3 (from llama-index-readers-web)
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting html2text<2025.0.0,>=2024.2.26 (from llama-index-readers-web)
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting newspaper3k<0.3.0,>=0.2.8 (from llama-index-readers-web)
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting playwright<2.0,>=1.30 (from llama-index-readers-web)
#   Downloading playwright-1.49.1-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting selenium<5.0.0,>=4.17.2 (from llama-index-readers-web)
#   Downloading selenium-4.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting spider-client<0.0.28,>=0.0.27 (from llama-index-readers-web)
#   Downloading spider-client-0.0.27.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.18.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.59.9)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.15->llama-index) (2.0.37)
# Collecting dataclasses-json (from llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (1.2.18)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (2024.10.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (3.4.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (11.1.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (9.0.0)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (4.67.1)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.15->llama-index) (1.17.2)
# Collecting llama-cloud<0.2.0,>=0.1.8 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.11-py3-none-any.whl.metadata (912 bytes)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-llms-openai-like<0.4.0,>=0.3.1->llama-index-llms-groq) (4.47.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.2)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index)
#   Downloading pypdf-5.2.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.5.20-py3-none-any.whl.metadata (6.9 kB)
# Collecting cssselect>=0.9.2 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (5.3.0)
# Collecting feedparser>=5.2.1 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 44.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: greenlet==3.1.1 in /usr/local/lib/python3.11/dist-packages (from playwright<2.0,>=1.30->llama-index-readers-web) (3.1.1)
# Collecting pyee==12.0.0 (from playwright<2.0,>=1.30->llama-index-readers-web)
#   Downloading pyee-12.0.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Collecting trio~=0.17 (from selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Downloading trio-0.28.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from feedfinder2>=0.0.4->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.8.2)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.4.0,>=0.3.1->llama-index-llms-groq) (0.27.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.4.0,>=0.3.1->llama-index-llms-groq) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.4.0,>=0.3.1->llama-index-llms-groq) (0.5.2)
# Collecting sortedcontainers (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium<5.0.0,>=4.17.2->llama-index-readers-web)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.7.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.13.0,>=0.12.15->llama-index)
#   Downloading marshmallow-3.26.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2025.1)
# Downloading llama_index-0.12.15-py3-none-any.whl (6.9 kB)
# Downloading groq-0.16.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.7/109.7 kB 3.7 MB/s eta 0:00:00
# Downloading llama_index_llms_groq-0.3.1-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_web-0.3.5-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.0 MB/s eta 0:00:00
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 37.7 MB/s eta 0:00:00
# Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Downloading llama_index_agent_openai-0.4.3-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.4.0-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.12.15-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.2 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.6.4-py3-none-any.whl (13 kB)
# Downloading llama_index_llms_openai-0.3.15-py3-none-any.whl (14 kB)
# Downloading llama_index_llms_openai_like-0.3.3-py3-none-any.whl (3.1 kB)
# Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.4.4-py3-none-any.whl (39 kB)
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 12.9 MB/s eta 0:00:00
# Downloading playwright-1.49.1-py3-none-manylinux1_x86_64.whl (44.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 15.4 MB/s eta 0:00:00
# Downloading pyee-12.0.0-py3-none-any.whl (14 kB)
# Downloading selenium-4.28.1-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 80.9 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.9 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading llama_cloud-0.1.11-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.6/250.6 kB 17.1 MB/s eta 0:00:00
# Downloading llama_parse-0.5.20-py3-none-any.whl (16 kB)
# Downloading pypdf-5.2.0-py3-none-any.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.7/298.7 kB 19.4 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.2 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 7.1 MB/s eta 0:00:00
# Downloading trio-0.28.0-py3-none-any.whl (486 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.3/486.3 kB 28.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.26.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 3.4 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: html2text, tinysegmenter, spider-client, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=8f8e5eb4d1a1abd0efecb6a556604525f4c2612c6082252eece79b45cc388abf
#   Stored in directory: /root/.cache/pip/wheels/23/58/7c/d9c8c4d924a1ac2b621add1b2c1d30b639629a33cfdfde6a45
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13539 sha256=c2d8a373b1f11cba5012a94a65388859f87bcccc95b628e7e5404c8edcb10472
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/f8/cce3a9ae6d828bd346be695f7ff54612cd22b7cbd7208d68f3
#   Building wheel for spider-client (setup.py) ... done
#   Created wheel for spider-client: filename=spider_client-0.0.27-py3-none-any.whl size=5976 sha256=f6a3a4922350c5bdc94704df204c865dcea9853edd67ab86ea40d541c6a4b408
#   Stored in directory: /root/.cache/pip/wheels/72/73/17/fab0356e5eec634ef9f9d0bdec011743f48ef380ee7307804f
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3342 sha256=2d0b192dcaf3a4126ed6ed29631a10b1332fe7b71de23b641f00b8dcb6fd301d
#   Stored in directory: /root/.cache/pip/wheels/80/d5/72/9cd9eccc819636436c6a6e59c22a0fb1ec167beef141f56491
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398379 sha256=c7abdf39d08c6c774d1d92db551d846767a14bd9aa96040d701eeb5482125b77
#   Stored in directory: /root/.cache/pip/wheels/3a/a1/46/8e68055c1713f9c4598774c15ad0541f26d5425ee7423b6493
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=7585ec010da9bf796c9078cc59bf102bf01b992a02bd5a2501fc29913f43e210
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built html2text tinysegmenter spider-client feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, striprtf, sortedcontainers, sgmllib3k, jieba3k, filetype, dirtyjson, wsproto, pypdf, pyee, outcome, mypy-extensions, marshmallow, html2text, feedparser, faiss-cpu, cssselect, chromedriver-autoinstaller, typing-inspect, trio, tiktoken, spider-client, requests-file, playwright, feedfinder2, trio-websocket, tldextract, llama-cloud, groq, dataclasses-json, selenium, newspaper3k, llama-index-core, llama-parse, llama-index-readers-web, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-llms-openai-like, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-llms-groq, llama-index-question-gen-openai, llama-index
# Successfully installed chromedriver-autoinstaller-0.6.4 cssselect-1.2.0 dataclasses-json-0.6.7 dirtyjson-1.0.8 faiss-cpu-1.10.0 feedfinder2-0.0.4 feedparser-6.0.11 filetype-1.2.0 groq-0.16.0 html2text-2024.2.26 jieba3k-0.35.1 llama-cloud-0.1.11 llama-index-0.12.15 llama-index-agent-openai-0.4.3 llama-index-cli-0.4.0 llama-index-core-0.12.15 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.6.4 llama-index-llms-groq-0.3.1 llama-index-llms-openai-0.3.15 llama-index-llms-openai-like-0.3.3 llama-index-multi-modal-llms-openai-0.4.3 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.4 llama-index-readers-llama-parse-0.4.0 llama-index-readers-web-0.3.5 llama-parse-0.5.20 marshmallow-3.26.0 mypy-extensions-1.0.0 newspaper3k-0.2.8 outcome-1.3.0.post0 playwright-1.49.1 pyee-12.0.0 pypdf-5.2.0 requests-file-2.1.0 selenium-4.28.1 sgmllib3k-1.0.0 sortedcontainers-2.4.0 spider-client-0.0.27 striprtf-0.0.26 tiktoken-0.8.0 tinysegmenter-0.3 tldextract-5.1.3 trio-0.28.0 trio-websocket-0.11.1 typing-inspect-0.9.0 wsproto-1.2.0

# %% [markdown]
# ## Import Required Modules
#
# We import necessary components from `llama_index` to set up web scraping, sentiment analysis, and competitive intelligence agents.

# %%
# %pip install llama-index-vector-stores-faiss
# Out:
# Collecting llama-index-vector-stores-faiss
#   Downloading llama_index_vector_stores_faiss-0.3.0-py3-none-any.whl.metadata (658 bytes)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-vector-stores-faiss) (0.12.15)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.11.11)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.18.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.26.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.3.1)
# Downloading llama_index_vector_stores_faiss-0.3.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: llama-index-vector-stores-faiss
# Successfully installed llama-index-vector-stores-faiss-0.3.0

# %%
from llama_index.core.tools import FunctionTool
from llama_index.core.agent.workflow import ReActAgent, AgentWorkflow
from llama_index.llms.openai import OpenAI
from llama_index.readers.web import SimpleWebPageReader
from llama_index.core.workflow import Context
from llama_index.vector_stores.faiss import FaissVectorStore
from llama_index.core import (VectorStoreIndex,StorageContext)
import faiss
import requests
from bs4 import BeautifulSoup

from llama_index.llms.groq import Groq
# Out:
# INFO:faiss.loader:Loading faiss with AVX2 support.
# INFO:faiss.loader:Successfully loaded faiss with AVX2 support.
# INFO:faiss:Failed to load GPU Faiss: name 'GpuIndexIVFFlat' is not defined. Will not load constructor refs for GPU indexes.

# %% [markdown]
# ## Define Tools
#
# We use LlamaIndex’s `SimpleWebPageReader` to scrape content from webpages. This tool extracts raw text from URLs for further processing.

# %%
def scrape_webpage(url: str) -> str:
    try:
        documents = SimpleWebPageReader(html_to_text=True).load_data([url])
        # Depending on use case and requirement use FAISS Index
        # d = 1536
        # faiss_index = faiss.IndexFlatL2(d)
        # vector_store = FaissVectorStore(faiss_index=faiss_index)
        # storage_context = StorageContext.from_defaults(vector_store=vector_store)
        # index = VectorStoreIndex.from_documents(documents, storage_context=storage_context)
        # return index
        # Depending on use case and requirement use FAISS Index
        return documents[0].text if documents else "No content found."
    except Exception as e:
        return f"Error: {e}"

scraper_tool = FunctionTool.from_defaults(fn=scrape_webpage, name="web_scraper", description="Extracts text from a webpage.")



async def write_report(ctx: Context, report_content: str) -> str:
    """Useful for writing a report on a given topic. Your input should be a markdown formatted report."""
    current_state = await ctx.get("state")
    current_state["report_content"] = report_content
    await ctx.set("state", current_state)
    return "Report written."
writer_tool = FunctionTool.from_defaults(fn=write_report, name="report_writer", description="writes")


async def record_notes(ctx: Context, notes: str, notes_title: str) -> str:
    """Useful for recording notes on a given topic. Your input should be notes with a title to save the notes under."""
    current_state = await ctx.get("state")
    if "research_notes" not in current_state:
        current_state["research_notes"] = {}
    current_state["research_notes"][notes_title] = notes
    await ctx.set("state", current_state)
    return "Notes recorded."
notes_tool = FunctionTool.from_defaults(fn=record_notes, name="note-taker", description="take notes")


async def review_report(ctx: Context, review: str) -> str:
    """Useful for reviewing a report and providing feedback. Your input should be a review of the report."""
    current_state = await ctx.get("state")
    current_state["review"] = review
    await ctx.set("state", current_state)
    return "Report reviewed."
reviewer_tool = FunctionTool.from_defaults(fn=review_report, name="reviews_report", description="reviewer")

# %% [markdown]
# ## Define Sentiment Analysis Tool
#
# We use OpenAI’s LLM to analyze sentiment from extracted content. The function classifies text into **Positive**, **Negative**, or **Neutral** sentiments.

# %%
def analyze_sentiment(text: str) -> str:
    prompt = f"Analyze the sentiment of the following text and return Positive, Negative, or Neutral: \n\n{text}"
    return llm.complete(prompt)

sentiment_tool = FunctionTool.from_defaults(fn=analyze_sentiment, name="sentiment_analysis", description="Analyzes sentiment of the given text.")

# %% [markdown]
# ## Define Competitive Intelligence Tool
#
# This tool processes extracted text to identify key insights, trends, and competitor strategies.

# %%
def extract_competitive_insights(text: str) -> str:
    prompt = f"Extract key insights, market trends, and competitor strategies from the following text: \n\n{text}"
    return llm.complete(prompt)

competitive_tool = FunctionTool.from_defaults(fn=extract_competitive_insights, name="competitive_intelligence", description="Extracts market trends and competitor insights.")

# %% [markdown]
# ## Initialize OpenAI LLM
#
# We use OpenAI’s GPT model to process and analyze scraped web data.

# %%
from google.colab import userdata
GROQ_API_KEY = userdata.get('GROQ_API_KEY')
OPENAI_API_KEY = userdata.get("OPENAI_API_KEY")


llama_llm = Groq(model="llama-3.3-70b-specdec", api_key=GROQ_API_KEY)
openai_llm = OpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)

llm = openai_llm

# %% [markdown]
# ## Define Multi-Agent System
#
# We create three AI agents:
# 1. **ResearchAgent** – Research market data from webpages.
# 2. **SentimentAgent** – Performs sentiment analysis on extracted text.
# 3. **WriteAgent** – Writes insights from data.
# 3. **ReviewAgent** – Reviews Contents from Reported Data.
#
# These agents collaborate to perform autonomous market intelligence tasks.

# %%
from llama_index.core.agent.workflow import FunctionAgent, ReActAgent

research_agent = ReActAgent(
    name="ResearchAgent",
    description="Useful for searching the web for information on a given topic and recording notes on the topic.",
    system_prompt=(
        "You are the ResearchAgent that can search the web for information on a given topic and record notes on the topic. "
        "Once notes are recorded and you are satisfied, you should hand off control to the WriteAgent to write a report on the topic. "
        "You should have at least some notes on a topic before handing off control to the WriteAgent."
        "Extract key insights, market trends, and competitor strategies"
        "restricts tokens to less than 50000"
    ),
    llm=llm,
    tools=[scraper_tool, notes_tool],
    can_handoff_to=["WriteAgent"],
)

write_agent = ReActAgent(
    name="WriteAgent",
    description="Useful for writing a report on a given topic.",
    system_prompt=(
        "You are the WriteAgent that can write a report on a given topic. "
        "Assess the sentiment on a given topic. "
        "Your report should be in a markdown format. The content should be grounded in the research notes. "
        "Once the report is written, you should get feedback at least once from the ReviewAgent."
    ),
    llm=llm,
    tools=[writer_tool, sentiment_tool],
    can_handoff_to=["ReviewAgent", "ResearchAgent"],
)

review_agent = ReActAgent(
    name="ReviewAgent",
    description="Useful for reviewing a report and providing feedback.",
    system_prompt=(
        "You are the ReviewAgent that can review the write report and provide feedback. "
        "Your review should either approve the current report or request changes for the WriteAgent to implement. "
        "If you have feedback that requires changes, you should hand off control to the WriteAgent to implement the changes after submitting the review."
    ),
    llm=llm,
    tools=[reviewer_tool,],
    can_handoff_to=["WriteAgent"],
)

# %% [markdown]
# 1. **ResearchAgent** : Research market data from webpages
# 2. **SentimentAgent** : Performs sentiment analysis on extracted text (Note: it is tool not agent)
# 3. **WriteAgent** : Writes insights from data
# 4. **ReviewAgent** : Reviews Contents from Reported Data
#
# These Agents Collaborate to perform autonomous market intelligence tasks
# <br>Note: Agent is sort of an SME and Tool are the skills or ability we provide to them

# %% [markdown]
# ## Set Up the Agent Workflow
#
# The `AgentWorkflow` enables our agents to work together sequentially, performing web scraping, sentiment analysis, and extracting insights.

# %%
agent_workflow = AgentWorkflow(
    agents=[research_agent, write_agent, review_agent],
    root_agent=research_agent.name
)

# %% [markdown]
# ## Running the Multi-Agent Workflow
#
# We test our system by extracting market intelligence from a sample webpage.

# %%
# url = "https://economictimes.indiatimes.com/"  # Replace with a real URL
# result = await agent_workflow.run(user_msg=f"Analyze industry trends for healthcare from {url}")

url = "https://economictimes.indiatimes.com/budget"
result = await agent_workflow.run(user_msg=f"Analyze the budget for me {url}")
result
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 20.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 19.940000 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 1.537886 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# ERROR:asyncio:Exception in callback Dispatcher.span.<locals>.wrapper.<locals>.handle_future_result(span_id='Workflow.run...-ceb413fe6d1f', bound_args=<BoundArgumen...mory': None})>, instance=<llama_index....x7dc1e8717710>, context=<_contextvars...x7dc1e8f686c0>)(<WorkflowHand...exceeded'}}")>) at /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py:273
# handle: <Handle Dispatcher.span.<locals>.wrapper.<locals>.handle_future_result(span_id='Workflow.run...-ceb413fe6d1f', bound_args=<BoundArgumen...mory': None})>, instance=<llama_index....x7dc1e8717710>, context=<_contextvars...x7dc1e8f686c0>)(<WorkflowHand...exceeded'}}")>) at /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py:273>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py", line 247, in _task
#     new_ev = await instrumented_step(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 367, in async_wrapper
#     result = await func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/agent/workflow/multi_agent_workflow.py", line 290, in run_agent_step
#     agent_output = await agent.take_step(
#                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/agent/workflow/react_agent.py", line 93, in take_step
#     async for r in response:
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/llms/callbacks.py", line 88, in wrapped_gen
#     async for x in f_return_val:
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/llms/openai/base.py", line 724, in gen
#     async for response in await aclient.chat.completions.create(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/resources/chat/completions.py", line 1720, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1849, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1543, in request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1629, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1676, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1629, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1676, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1629, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1676, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1644, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-XqxsrErw5IF0yK8HMOvuryK2 on tokens per min (TPM): Limit 60000, Used 58279, Requested 50030. Please try again in 48.309s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 285, in handle_future_result
#     raise exception
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py", line 445, in _run_workflow
#     raise exception_raised
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py", line 254, in _task
#     raise WorkflowRuntimeError(
# llama_index.core.workflow.errors.WorkflowRuntimeError: Error in step 'run_agent_step': Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-XqxsrErw5IF0yK8HMOvuryK2 on tokens per min (TPM): Limit 60000, Used 58279, Requested 50030. Please try again in 48.309s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py in _task(name, queue, step, config)
#     246                             try:
# --> 247                                 new_ev = await instrumented_step(**kwargs)
#     248                                 break  # exit the retrying loop
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/agent/workflow/multi_agent_workflow.py in run_agent_step(self, ctx, ev)
#     289
# --> 290         agent_output = await agent.take_step(
#     291             ctx,
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/agent/workflow/react_agent.py in take_step(self, ctx, llm_input, tools, memory)
#      92         response = await self.llm.astream_chat(input_chat)
# ---> 93         async for r in response:
#      94             raw = r.raw.model_dump() if isinstance(r.raw, BaseModel) else r.raw
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/llms/callbacks.py in wrapped_gen()
#      87                         try:
# ---> 88                             async for x in f_return_val:
#      89                                 dispatcher.event(
#
# /usr/local/lib/python3.11/dist-packages/llama_index/llms/openai/base.py in gen()
#     723             first_chat_chunk = True
# --> 724             async for response in await aclient.chat.completions.create(
#     725                 messages=message_dicts,
#
# /usr/local/lib/python3.11/dist-packages/openai/resources/chat/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1719         validate_response_format(response_format)
# -> 1720         return await self._post(
#    1721             "/chat/completions",
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1848         )
# -> 1849         return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#    1850
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1542
# -> 1543         return await self._request(
#    1544             cast_to=cast_to,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1628                 await err.response.aclose()
# -> 1629                 return await self._retry_request(
#    1630                     input_options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1675
# -> 1676         return await self._request(
#    1677             options=options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1628                 await err.response.aclose()
# -> 1629                 return await self._retry_request(
#    1630                     input_options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1675
# -> 1676         return await self._request(
#    1677             options=options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1628                 await err.response.aclose()
# -> 1629                 return await self._retry_request(
#    1630                     input_options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1675
# -> 1676         return await self._request(
#    1677             options=options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1643             log.debug("Re-raising status error")
# -> 1644             raise self._make_status_error_from_response(err.response) from None
#    1645
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-XqxsrErw5IF0yK8HMOvuryK2 on tokens per min (TPM): Limit 60000, Used 58279, Requested 50030. Please try again in 48.309s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# The above exception was the direct cause of the following exception:
#
# WorkflowRuntimeError                      Traceback (most recent call last)
# <ipython-input-21-9d6682caaca9> in <cell line: 1>()
#       3
#       4 url = "https://economictimes.indiatimes.com/budget"
# ----> 5 result = await agent_workflow.run(user_msg=f"Analyze the budget for me {url}")
#       6 result
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py in _run_workflow()
#     443                     ctx.write_event_to_stream(StopEvent())
#     444
# --> 445                     raise exception_raised
#     446
#     447                 if not we_done:
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py in _task(name, queue, step, config)
#     252                             except Exception as e:
#     253                                 if config.retry_policy is None:
# --> 254                                     raise WorkflowRuntimeError(
#     255                                         f"Error in step '{name}': {e!s}"
#     256                                     ) from e
#
# WorkflowRuntimeError: Error in step 'run_agent_step': Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-XqxsrErw5IF0yK8HMOvuryK2 on tokens per min (TPM): Limit 60000, Used 58279, Requested 50030. Please try again in 48.309s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ## Streaming Agent Events
#
# We monitor agent actions by streaming events, displaying web scraping, sentiment analysis, and intelligence gathering steps.

# %%
from llama_index.core.agent.workflow import AgentOutput, ToolCall, ToolCallResult

url = "https://economictimes.indiatimes.com/budget"
handler = agent_workflow.run(user_msg=f"Analyze the budget for me {url}")

current_agent = None
async for event in handler.stream_events():
    if hasattr(event, "current_agent_name") and event.current_agent_name != current_agent:
        current_agent = event.current_agent_name
        print(f"\n{'='*50}")
        print(f"🤖 Agent: {current_agent}")
        print(f"{'='*50}\n")
    elif isinstance(event, AgentOutput):
        if event.response.content:
            print("📤 Output:", event.response.content)
        if event.tool_calls:
            print("🛠️ Tools Used:", [call.tool_name for call in event.tool_calls])
    elif isinstance(event, ToolCallResult):
        print(f"🔧 Tool Result ({event.tool_name}): {event.tool_output}")
# Out:
# ==================================================
# 🤖 Agent: ResearchAgent
# ==================================================
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📤 Output: Thought: The current language of the user is: English. I need to use a tool to help me gather more information about the budget from the provided link.
# Action: web_scraper
# Action Input: {"url":"https://economictimes.indiatimes.com/budget"}
# 🛠️ Tools Used: ['web_scraper']
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 0.463645 seconds
# 🔧 Tool Result (web_scraper): [![The Economic Times](https://img.etimg.com/photo/msid-76931895/et-
# logo.jpg)](/ "The Economic Times")[Budget
# 2025](https://economictimes.indiatimes.com/budget "Budget 2025")
#
# English EditionEnglish
# Edition[हिन्दी](https://hindi.economictimes.com/)[ગુજરાતી](https://gujarati.economictimes.com/)[मराठी](https://marathi.economictimes.com/)[বাংলা](https://bengali.economictimes.com/)[ಕನ್ನಡ](https://kannada.economictimes.com/)[മലയാളം](https://malayalam.economictimes.com/)[தமிழ்](https://tamil.economictimes.com/)[తెలుగు](https://telugu.economictimes.com/)
#
# | 01 February, 2025, 12:54 PM IST | [Today's ePaper](https://epaper.indiatimes.com/timesepaper/publication-the-economic-times,city-delhi.cms)
#
# [ My Watchlist
# ](https://economictimes.indiatimes.com/watchlist?source=homepage&medium=header&campaign=watchlist)[Subscribe](javascript:cdpGoToPlan\(\))
#
# [Sign In](javascript:objUser.login\(\))
#
# Search
#
# +
#
# [Home](/)
#
# [BUDGET'25](https://economictimes.indiatimes.com/budget)
#
# [ETPrime](https://economictimes.indiatimes.com/prime)
#
# [Markets](https://economictimes.indiatimes.com/markets)
#
# [Market Data](https://economictimes.indiatimes.com/markets/live-coverage)
#
# [News](https://economictimes.indiatimes.com/news)
#
# [Industry](https://economictimes.indiatimes.com/industry)
#
# [![EaseBuzz](https://img.etimg.com/photo/msid-117790307/et-
# EaseBuzz.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6906359976&iu=/7176/Economictimes/Budget/ET_Budget_Trackers/ET_Budget_CLK_Tracker_21
# "EaseBuzz")
#
# [Rise](https://economictimes.indiatimes.com/small-biz)
#
# [Politics](/news/politics)
#
# [Wealth](https://economictimes.indiatimes.com/personal-finance)
#
# [MF](https://economictimes.indiatimes.com/mutual-funds)
#
# [Tech](https://economictimes.indiatimes.com/tech)
#
# [Careers](https://economictimes.indiatimes.com/jobs)
#
# [Opinion](https://economictimes.indiatimes.com/opinion)
#
# [NRI](https://economictimes.indiatimes.com/nri)
#
# [Panache](https://economictimes.indiatimes.com/panache)
#
# [Videos](/multimedia/type-video.cms)
#
# More Menu
#
# [![Salesforce](https://img.etimg.com/photo/msid-111887055/et-
# Salesforce.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6906905665&iu=/7176/Economictimes/Budget/ET_Budget_Trackers/ET_Budget_CLK_Tracker_7
# "Salesforce")
#
# [Budget Headlines](https://economictimes.indiatimes.com/budget/budget-
# headlines?adcode=101)
#
# [![CoinDCX](https://img.etimg.com/photo/msid-117609895/et-
# CoinDCX.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6907858753&iu=/7176/Economictimes/Budget/ET_Budget_CLK_Tracker_16
# "CoinDCX")
#
# [Budget & Markets](https://economictimes.indiatimes.com/budget/markets-and-
# budget?adcode=106)
#
# [![DLF](https://img.etimg.com/photo/msid-117526938/et-
# dlf.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6901151514&iu=/7176/Economictimes/Budget/ET_Budget_Trackers/ET_Budget_CLK_Tracker_1
# "DLF")
#
# [CXO Corner](https://economictimes.indiatimes.com/budget/cxo-
# corner?adcode=104)
#
# [![pnb](https://img.etimg.com/photo/msid-117607556/et-
# pnb.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6906905665&iu=/7176/Economictimes/Budget/ET_Budget_Trackers/ET_Budget_CLK_Tracker_7
# "pnb")
#
# [Game Changer Budget](https://economictimes.indiatimes.com/budget/game-
# changer-budget-2025?adcode=102)
#
# [![LightNodes](https://img.etimg.com/photo/msid-117649799/et-
# LightNodes.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6907858753&iu=/7176/Economictimes/Budget/ET_Budget_CLK_Tracker_16
# "LightNodes")
#
# [Economy Insight](https://economictimes.indiatimes.com/budget/economy-
# insight?adcode=103)
#
# [Taxes & You](https://economictimes.indiatimes.com/budget/taxes-and-
# you?adcode=105)
#
# [Loans](https://economictimes.indiatimes.com/wealth/borrow)
#
# [Budget Game](https://economictimes.indiatimes.com/budget/budget-question-
# answer-game)
#
# [Sectors in Focus](https://economictimes.indiatimes.com/industry)
#
# [Banking](https://economictimes.indiatimes.com/industry/banking/finance)
#
# [Energy](https://economictimes.indiatimes.com/industry/energy)
#
# [![VikramSolar](https://img.etimg.com/photo/msid-117738846/et-
# VikramSolar.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6908889544&iu=/7176/Economictimes/Budget/ET_Budget_CLK_Tracker_20
# "VikramSolar")
#
# [Travel](https://economictimes.indiatimes.com/industry/services/travel)
#
# [RISE](https://economictimes.indiatimes.com/small-biz)
#
# [![EaseBuzz](https://img.etimg.com/photo/msid-117790307/et-
# EaseBuzz.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6906359976&iu=/7176/Economictimes/Budget/ET_Budget_Trackers/ET_Budget_CLK_Tracker_21
# "EaseBuzz")
#
# [Tech](https://economictimes.indiatimes.com/tech)
#
# [Auto](https://economictimes.indiatimes.com/industry/auto)
#
# [![MG](https://img.etimg.com/photo/msid-117789772/et-
# MG.jpg)](http://pubads.g.doubleclick.net/gampad/clk?id=6910519433&iu=/7176/Economictimes/Budget/ET_Budget_Trackers/ET_Budget_CLK_Tracker_27
# "MG")
#
# [Business News](https://economictimes.indiatimes.com "The Economic
# Times")›Budget 2025
#
# ## [Budget Live: Sitharaman may have just saved you Rs 80,000 in
# taxes](http://economictimes.indiatimes.com/news/newsblogs/budget-2025-live-
# updates-union-budget-finance-minister-nirmala-sitharaman-speech-live-key-
# announcements-customs-duty-tax-takeaways-1-feb-budget-impacts-latest-
# news/liveblog/117807015.cms "Budget Live: Sitharaman may have just saved you
# Rs 80,000 in taxes")
#
# [No income tax for income up to Rs 12 lakh
# *T&C](http://economictimes.indiatimes.com/wealth/tax/income-tax-
# budget-2025-live-updates-tax-slab-fy25-26-new-old-tax-regime-standard-
# deduction-sec-80c-87a-rebate-nirmala-sitharaman-union-budget-
# announcements-1-february-2025/liveblog/117798057.cms "No income tax for income
# up to Rs 12 lakh *T&C")[D-St jittery: Sensex, Nifty see wild
# swings](http://economictimes.indiatimes.com/markets/stocks/live-blog/bse-
# sensex-today-live-updates-nifty-50-stock-market-on-union-budget-2025-nirmala-
# sitharaman-speech-01-february-2025/liveblog/117809746.cms "D-St jittery:
# Sensex, Nifty see wild swings")
#
# [SENSEX77248.29-252.28](/indices/sensex_30_companies)
#
# [NIFTY23403.75-104.66](/indices/nifty_50_companies)
#
# [GOLD (Rs/10 GRMS)82007.0119.00](/commoditysummary/symbol-GOLD.cms)
#
#  __Live Updates
#
# [](/budget)
#
#   * Tax Updates Live
#   * Budget Live
#   * Markets Live
#
#   * ### [Income Tax Slabs Budget 2025 Live Updates: No income tax payable on annual income of up to Rs 12 lakh, standard deduction stays same in both regimes? FM presents Union Budget 2025-26](https://economictimes.indiatimes.com/wealth/tax/income-tax-budget-2025-live-updates-tax-slab-fy25-26-new-old-tax-regime-standard-deduction-sec-80c-87a-rebate-nirmala-sitharaman-union-budget-announcements-1-february-2025/liveblog/117798057.cms "Income Tax Slabs Budget 2025 Live Updates: No income tax payable on annual income of up to Rs 12 lakh, standard deduction stays same in both regimes? FM presents Union Budget 2025-26")
#
# 01 Feb 2025 | 12:53:14 PM IST
#
# ![](https://img.etimg.com/thumb/msid-117798057,width-630,resizemode-4,imgsize-974344/income-
# tax-budget-2025-live-updates-tax-slab-fy25-26-new-old-tax-regime-standard-
# deduction-sec-80c-87a-rebate-nirmala-sitharaman-union-budget-
# announcements-1-february-2025.jpg)
#
# 12:53:14 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Effective income of up to Rs 12,75,000
# for salaried taxpayers tax-free under the new tax regime is tax-free. See how
#
# Budget 2025 Income Tax Live Updates: Post FM Nirmala Sitharaman's budget
# announcement, effective income of up to Rs 12,75,000 for salaried taxpayers is
# tax-free. This includes a basic income exemption limit of up to Rs 12,000,000
# and a standard deduction of up to Rs 75,000.
#
# According to Manoranjan Sharma, Chief Economist at Infomerics Ratings, "As
# visualized by us and strongly stressed on multiple channels and in various
# mediums, the middle class has been given a welcome relief with no income tax
# up to Rs. 12 lakhs income. For salaried persons, it will go up to Rs. 12.75
# lakhs by factoring in standard deduction. In view of the ravages of the
# inflationary spiral and the shrinking disposable income, this enhanced income
# tax limit will be welcome across the development spectrum."
#
# **Read more here:[How income up to Rs 12,00,000 is tax-free under the new
# regime ](https://economictimes.indiatimes.com/wealth/tax/section-87a-tax-
# rebate-changes-in-union-budget-2025/articleshow/117735302.cms
# "https://economictimes.indiatimes.com/wealth/tax/section-87a-tax-rebate-
# changes-in-union-budget-2025/articleshow/117735302.cms")**
#
#
# 12:47:47 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Here is how old tax regime and new tax
# regime will look like post Budget 2025-26
#
# Income Tax Budget 2025 Live Updates: The new proposed tax regime, post FM
# Nirmala Sitharaman's budget announcement, looks like this:
#
#
#     * Zero to Rs 4,00,000—No Tax
#     * Rs 4,00,000 to Rs 8,00,000---5%
#     * Rs 8,00,0001 to Rs 12,00,000---10%
#     * Rs 12,00,001 to Rs 16 lakh---15%
#     * Rs 16,00,001 to Rs 20 lakh---20%
#     * Rs 20,00,001 to Rs 24 lakh - 25%
#     * Above 24 lakh---30%
#
# The old tax regime, where no changes have been announced, looks like this (for
# those aged under 60).
#
#
#     * No income tax on annual incomes-Rs 2,50,000
#     * Between Rs. 2,50,001 and Rs 5,00,000-5%
#     * Between Rs 5,00,001 to Rs 10,00,000-20%
#     * Over Rs 10,00,000- 30%
#
#
#
# 12:37:24 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Middle Class Taxpayers Benefit from
# Increased Rebate Limit Under Section 87A
#
# Income Tax Budget 2025 Live Updates: In a much anticipated move, the
# government has announced an increase in the rebate limit under Section 87A of
# the Income Tax Act. The rebate limit has been raised from Rs 7 lakhs to Rs 12
# lakhs, offering significant tax relief to the middle class. For salaried
# individuals, who are eligible for a standard deduction of Rs 75,000, the
# effective rebate limit now stands at Rs 12.75 lakhs.
#
# "This increase is expected to provide much-needed financial relief to many
# taxpayers, reducing their overall tax burden and improving disposable income.
# However, it's important to note that this benefit will not be applicable to
# income taxed under special tax rates, as clarified by the Finance Minister.
# This means individuals with income subject to special tax rates such as
# capital gains or certain other categories will not be eligible for this
# rebate", explains CA Jigar Suba.
#
# The move is seen as a step toward enhancing financial stability for the
# middle-income group, and is expected to have a positive impact on their
# purchasing power in the coming fiscal year.
#
# 12:35:09 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: How has annual income of up to Rs
# 12,00,000 become tax-free under the new tax regime in Budget 2025-26?
#
# Income Tax Budget 2025 Live Updates: As per the budget memorandum, "to enhance
# the limit of total income for rebate in clauses (a) and (b) of the first
# proviso under section 87A, on which the income tax is payable as per the rates
# of income tax under sub-section (1A) of section 115BAC, from Rs. 7,00,000 to
# Rs. 12,00,000 and the limit of rebate in clause (a) of first proviso to
# section 87A from Rs. 25,000 to Rs. 60,000,”
#
# 12:32:36 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Section 87A rebate raised from Rs 25,000
# to Rs 60,000 in new tax regime
#
# Income Tax Union Budget 2025: In her Budget speech, FM Nirmala Sitharaman
# hiked the basic income exemption limit from Rs 3 lakh to Rs 4 lakh. Since the
# 87A rebate was raised from Rs 25,000 to Rs 60,000, individuals with annual
# income from up to Rs 12,00,000 will see their tax liability reduced to 0. Read
# more about this here: **[Section 87A rebate in new regime hiked in Budget
# 2025, here is how it will impact
# you](https://economictimes.indiatimes.com/wealth/tax/basic-exemption-limit-
# changes-in-budget-2025/articleshow/117737776.cms
# "https://economictimes.indiatimes.com/wealth/tax/basic-exemption-limit-
# changes-in-budget-2025/articleshow/117737776.cms")**
#
#
# 12:26:38 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Big relief for the middle-class in the
# new tax regime, no income tax payable on annual income of up to Rs 12 lakh
#
# Income Tax Budget 2025 Live Updates: FM Sitharaman has delivered a significant
# tax relief for taxpayers in her budget speech by making annual income of up to
# Rs 12 lakh in the new tax regime tax-free.
#
# "Big relief for taxpayers! Under the new tax regime, income up to Rs 12 lakh
# will now be tax-free, significantly reducing the financial burden on the
# middle class. This bold move enhances disposable income, encourages spending,
# and promotes economic growth. By simplifying taxation and easing compliance,
# the government reinforces its commitment to a taxpayer-friendly system. This
# reform not only benefits salaried individuals but also supports businesses and
# investments, driving overall prosperity. With a focus on financial empowerment
# and ease of living, this tax relief is a major step toward a more inclusive
# and growth-oriented economy", says Adhil Shetty, Bankbazaar
#
# 12:24:27 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: BIG overhaul of income tax slab rates
# under the new tax regime!
#
# Income Tax Budget 2025 Live Updates: Here is how the new tax regime will now
# look like:
#
# Zero to Rs 4,00,000— No Tax
# Rs 4,00,000 to Rs 8,00,000---5%
# Rs 8,00,0001 to Rs 12,00,000---10%
# Rs 12,00,001 to 16 lakh rupees---15%
# Rs 16,00,001 to 20 lakh rupees---20%
# Rs 20,00,001 to 24 lakh rupees-- 25%
# Above 24 lakh---30%
#
#
# 12:14:01 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: No income tax on annual income of up to
# Rs 12 lakh in new tax regime
#
# Income Tax Budget 2025 Live Updates: No income tax for salaried people on
# income of up to Rs 12,75,000
#
# 12:12:05 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Withdrawals from National Savings Scheme
# post August 29, 2024 made tax-free
#
# Income Tax Budget 2025 Live Updates: "A number of senior and very senior
# citizens have very old National Savings Scheme (NSS) accounts. As interest is
# no longer payable on such accounts, I propose to exempt withdrawals made from
# NSS by individuals on or after 29th August, 2024."
#
# 12:08:54 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: TDS exemption limit for rent payment
# hiked in Budget 2025-26
#
# Income Tax Budget 2025 Live Updates: In her speech, FM said that the annual
# limit of Rs 2.40 lakh for TDS on rent is being increased to Rs 6 lakh. "This
# will reduce, this will reduce the number of transactions liable to TDS, thus
# benefiting small tax payers receiving small payments", she said.
#
# 12:06:51 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: TDS limit for senior citizen on interest
# hiked in Budget 2025-26
#
# Income Tax Budget 2025 Live Updates: According to FM Nirmala Sitharaman, "I
# propose to rationalize tax deductions at source (TDS) by reducing the number
# of rates and thresholds about which TDS is deductible. Further, threshold
# amounts for tax deduction will be increased for better clarity and uniformity.
# The limit for tax deduction on interest for senior citizens is being doubled
# from the present Rs 50,000 to Rs 1,00,000."
#
#
# 12:04:52 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: New Income Tax Bill to be clear, direct,
# and simpler, to embody essence of parent law, says FM
#
# India Budget 2025 Income Tax Live Updates: In her speech, FM said that the
# "New Income Tax Bill will carry forward the same spirit of Nyaya in its
# drafting as well. The new bill will be clear, clear and direct, with close to
# half of the present law in terms of both chapters and words; it will be
# simple to understand for taxpayers and tax administrators, leading to tax
# certainty and reduced litigation."
#
# 12:00:00 PM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Interactive flat-panel LCDs to cost more
#
# Income Tax Union Budget 2025: In her speech, FM Sitharaman noted that "In line
# with our Make in India policy and to rectify inward duty structure, I propose
# to increase the Basic Custom Duty (BCD) on interactive flat panel display from
# 10% to 20% and reduce the BCD to 5% on open cells and other components. " This
# is set to make interactive, flat-panel LCDs costlier.
#
# 11:58:06 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Income tax assessment to work on the
# principle of "first trust, then scrutinise", says FM Sitharaman
#
# 11:56:39 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Full exemption of custom duty proposed on
# 36 life-saving drugs
#
# Income Tax Budget 2025 Live Updates: In her budget speech, FM Sitharaman
# proposed full exemption of custom duty on 36 lifesaving drugs. This is set to
# benefit patients suffering from cancer, severe chronic diseases and other rare
# illnesses.
#
# 11:52:15 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Jan Vishwas Act to decriminalise multiple
# provisions, says FM in Budget speech
#
# Income Tax Budget 2025 Live Updates: In her Budget 2025-26 speech, FM
# Sitharaman noted that with Jan Vishwas Act 2023, more than 180 legal
# provisions were
# decriminalized. "The government will now bring about Jan Vishwa Bill 2.0,
# which will further decriminalize more than 100 provisions in various laws,"she
# added
#
# 11:48:51 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Revamped, simplified CKYC registry for
# pension products to be launched soon
#
# Income Tax Budget 2025 Live Updates: In her speech, FM Sitharaman noted that a
# forum for regulatory coordination and development of pension products will be
# set up to implement the earlier announcement on simplifying the KYC processes.
# The revamped central KYC registry will be rolled out in 2025
#
# 11:45:27 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: New Income Tax bill to be introduced by
# FM Sitharaman next week
#
# Income Tax Budget 2025 Live Updates: In her speech, FM announced that she will
# be tabling the new income tax bill in the parliament next week
#
# 11:44:14 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Big relief for homebuyers stuck in
# stressed housing projects in Budget 2025-26
#
# Income Tax Union Budget 2025: According to FM Sitharaman, "Under the SWAMIH 2
# Investment Fund, 50,000 dwelling units in stressed housing projects have been
# completed and keys handed over to home buyers. Another 40,000 units will be
# completed in 2025, further helping middle-class families who are paying EMIS
# on loans taken for apartments while also paying rent for their current
# dwellings. Building on this success, SWAMIH 2 Fund will be established as a
# blended finance facility with contributions from the government, banks, and
# private investors. An additional fund allocation of Rs 15,000 crore will aim
# for expeditious completion of another one lakh units."
#
# 11:40:18 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: UDAAN scheme has given wings to
# aspirations of India's middle-class, says FM
#
# Income Tax Union Budget 2025: In her budget speech, FM Sitharaman noted that
# inspired by that success of UDAN, a modified scheme will be launched
# to enhance regional connectivity to 120 new destinations and carry four crore
# passengers in the next 10 years. "The scheme will also support helipads and
# smaller airports in hilly, aspirational, and northeast regional districts,"
# she added.
#
# 11:33:23 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Social Security benefits for gig workers
# announced in Union Budget 2025-26
#
# Income Tax Union Budget 2025: As per the FM, "Social security scheme for
# welfare of online platform workers, gig workers associated with online
# platforms provide great dynamism to the new age services economy. Recognizing
# their contribution, our government will arrange for their identity cards and
# registration on the E- Shram portal. They will be provided health care under
# PM Jan Arogya Yojana; this facility is likely to assist nearly one crore gig
# workers."
#
# 11:31:37 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: PM Swanidhi scheme to be revamped, offer
# credit with limit of up to Rs 30,000
#
# Income Tax Union Budget 2025: In her Budget speech, FM noted that the PM
# Swanidhi Scheme has benefited more than 68 lakh street vendors, giving them
# respite from high-interest informal sector loans. "Building on this success,
# the scheme will be revamped with enhanced loans from banks and UPI-linked
# credit cards
# with Rs 30,000 limit," she added.
#
# 11:27:39 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Center of excellence in AI for education
# to be set up with outlay of Rs 500 crores, says FM
#
# Income Tax Union Budget 2025: As per FM Sitharaman, "I had announced three
# centers of excellence in artificial intelligence for agriculture, health, and
# sustainable cities in 2023. Now a center of excellence in artificial
# intelligence for education will be set up with a total outlay of 500 crores.
# We are also expanding our medical education. Our government has added almost
# 1.1 lakh undergraduate and postgraduate medical education seats in 10 years,
# an increase of 130% in the next year. 10,000 additional seats will be added in
# medical colleges and hospitals towards the goal of adding 75,000 seats in the
# next five years."
#
# 11:24:38 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Higher credit limit to help farmers
#
# Budget 2025 Income Tax Live Updates: As per Adhil Shetty, CEO of
# Bankbazaar.com, "The continuation of Kisan Credit Cards (KCC) as a financial
# enabler for 7.7 crore farmers, fishermen, and dairy farmers underscores the
# government's commitment to strengthening rural credit access. By increasing
# the loan limit under the modified interest subvention scheme from Rs 3,00,000
# to Rs 5,00,000, the move enhances liquidity, allowing small and marginal
# farmers to sustain and expand their agricultural activities. This initiative
# not only eases short-term financial burdens but also promotes self-sufficiency
# in food production, ensuring stability in the rural economy."
#
# 11:16:31 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Kisan Credit card limit enhanced from Rs
# 3 lakh to Rs 5 lakh
#
# Income Tax Budget 2025 Live Updates: According to FM, "Kisan credit cards
# facilitate short-term loans for 7.7 crore farmers, fishermen and dairy
# farmers; the loan limit under modified interest subvention scheme will be
# enhanced from three lakh rupees to five lakh rupees for loans taken through
# the KCC (Kisan Credit Card)
#
# 11:14:53 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Budget to focus on 6 pillars like tax,
# power, urban development and more
#
# Income Tax Budget 2025 Live Updates: In her Budget speech, the FM emphasised
# that that this budget will be focused on several reforms across 6 domains:
# taxation, power sector, urban development, mining, and financial sector &
# regulatory reforms.
#
# 11:13:30 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Budget 2025-26 should focus on enhancing
# regulatory compliances for taxpayers
#
# Income Tax Budget 2025 Live Updates: One of the most prominent demands from
# the ongoing budget presentation is the introduction of measures to simplify
# and streamline tax-related laws. As per Rajarshi Dasgupta, Executive Director-
# Tax, AQUILAW, "Regulatory compliance seems to be a major obstacle to economic
# freedom for individuals and small businesses. India Inc., in order to improve
# domestic growth, should advocate for policies that enhance economic freedom
# for individuals and small businesses with a focus on digitisation,
# decriminalization, and divestment of unnecessary government functions like
# land, labor, building regulations, and utilities.”
#
# 11:08:54 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Budget aims to initiate transformative
# reforms for Viksit Bharat
#
# Budget 2025 Income Tax Live Updates: According to FM, "We envision 100%
# quality, good school education, access to high-quality, affordable, and
# comprehensive health care, 100% skilled labor with meaningful employment, 70%
# women in economic activities, and empowering farmers, making our country the
# food basket of the world." As per Sitharaman, this budget will focus on youth,
# women, and annadata, i.e., farmers.
#
# 11:10:17 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Budget to focus on India's rising middle
# class
#
# Income Tax Budget 2025 Live Updates: FM rises to present the Union Budget,
# emphasises that the budget would focus on enhancing the spending power of
# India's rising middle class
#
# 10:55:10 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: FM Sitharaman to table the Budget 2025-26
# documents at 11 am
#
# India Budget 2025 Income Tax live Updates: You can watch the live proceedings
# of the Budget on the government’s official union budget website-
# indiabudget.gov.in. You can also catch FM Nirmala Sitharaman delivering her
# budget speech on the YouTube and TV channels of Sansad TV. The YouTube channel
# of PIB (Press Information Bureau) will also broadcast the live speech, which
# will begin around 11 am.
#
# 10:50:25 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: What are some of the most popular
# deductions that taxpayers are hoping will be introduced in the new tax regime
# as well in Union Budget 2025-26?
#
# Income Tax Union Budget 2025: According to experts, these are the
# exemptions/deductions that middle-class taxpayers are hoping will be
# introduced under the new regime:
#
#     * Section 80C: Allow deductions up to Rs 2 lakhs for life insurance premiums, employees’ Provident Fund contributions, etc.
#     * Section 80D: Extend the deduction up to Rs 1 lakh for health insurance premiums for self and family, addressing the growing burden of medical expenses.
#     * Section 80TTB: Include a deduction of up to Rs 50,000 for senior citizens earning interest from deposits with banks, post offices, etc.
#     * Section 10(13A): Allow salaried taxpayers to claim HRA deductions for rental expenditures under the new tax regime.
#
#
# 10:45:05 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: Will FM Nirmala Sitharaman have something
# in store in Union Budget 2025-26 for those looking to buy a house?
#
# Income Tax Budget 2025 Live Updates: As we approach the upcoming budget,
# Pradeep Aggarwal, Founder & Chairman, Signature Global (India) Ltd., notes
# that revising the current tax exemption limit on housing loans to Rs 5 lakhs,
# in line with rising property prices and construction costs, could provide
# significant relief to homebuyers. This step would directly support millions of
# aspiring homeowners and boost demand across the sector. This limit currently
# stands at Rs 2 lakh only for the interest portion of the home loan and is
# exclusively available under the old tax regime.
#
# 10:34:03 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: Will the standard deduction limit be
# increased in both old and new tax regimes?
#
# Income Tax Union Budget 2025: Experts note that since the government aims to
# shift more taxpayers to the simplified or new tax regime, chances of
# incentivizing the old tax regime by hiking standard deduction limits under
# this regime are unlikely. Hence, even if the government hikes the standard
# deduction limit in Budget 2025, it is likely to be limited to the new tax
# regime. Keep in mind that the government introduced a standard deduction of Rs
# 50,000 in Budget 2023 in the new tax regime, which was hiked to Rs 75,000 in
# Budget 2024. Under the old tax regime, the standard deduction stands at Rs
# 50,000.
#
# 10:34:11 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: How much salary is taxable?
#
# Income Tax Budget 2025 Live Updates: Under the old tax regime, annual income
# over Rs 2,50,000 is subject to income taxes. This means that the basic
# exemption limit under the old tax regime stands at Rs 2,50,000. Similarly,
# under the new tax regime, income over and above Rs 3,00,000 is subject to
# income taxes i.e. the basic income exemption limit under the new tax regime
# stands at Rs 3,00,000.
#
# 10:26:13 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: Is Rs 7 lakh income tax-free in the
# current budget?
#
# Income Tax Budget 2025 Live Updates: Under the new tax regime, income of up to
# Rs 7,00,000 is tax-free due to a rebate offered under Section 87A. This means
# if you earn up to Rs 7,00,000 and opt for the new tax regime, your tax
# liability will be reduced to 0.
#
# 10:25:06 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: What is the current income tax slab in the
# old regime?
#
# Income Tax Union Budget 2025: For those aged under 60), there is no income tax
# on annual incomes up to Rs 2,50,000. Between Rs. 2,50,001 and Rs 5,00,000, a
# 5% tax is applicable. Between Rs 5,00,001 and Rs 10,00,000, a 20% tax rate is
# levied. Over Rs 10,00,000, i.e., from Rs 10,00,001 and above, a 30% rate is
# applicable.
#
# 10:20:31 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: What is current income tax slab?
#
# Income Tax Union Budget 2025: Under the new, default tax regime, there is no
# income tax levied on annual income of up to Rs. 3,00,000. Between Rs. 3,00,001
# to Rs. 7,00,000, a 5% tax is levied. From Rs. 7,00,001 to Rs. 10,00,000, a 10%
# tax is levied. From Rs. 10,00,001 to Rs. 12,00,000, a 15% tax is applicable.
# From Rs. 12,00,001 to Rs. 15,00,000, a tax rate of 20% is applied. Above Rs.
# 15,00,000, a 30% tax rate is applicable.
#
# 10:09:17 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: Will FM Nirmala Sitharaman create a
# separate section for claiming deductions for life and health insurance
# premiums in the new regime in Union Budget 2025-26?
#
# Income Tax Union Budget 2025: Under the new tax regime, there are no
# deductions available for life or health insurance premiums paid. In the old
# tax regime, while deductions for life insurance premiums can be claimed under
# Section 80C, deductions for health insurance premiums paid for self, spouse,
# or dependent parents can be claimed under Section 80D.
#
# According to Sumit Bohra, President, Insurance Brokers Association of India
# (IBAI), "As we approach the Union Budget for 2025, we are looking forward to
# the
# government to provide tax exemption on GST or moderation of GST rate across
# the health and term insurance premium. There should also be a separate section
# apart from section 80D and 80C for deduction or exemption for insurance
# policies that should cover health insurance, personal accident, home insurance
# and life
# insurance. This deduction request for exemption for insurance policies should
# also be part of the new tax regime."
#
# 10:03:11 AM IST, 01 Feb 2025
#
# Income Tax Slabs News Live Updates: What are the present tax slabs applicable
# for super senior citizens, i.e., those aged over 80 under the old tax regime?
#
# Income Tax Union Budget 2025: At present, super senior citizens, i.e., those
# aged over 80, are subject to the following tax slabs under the old tax regime:
#
#
#     * Up to Rs 2,50,000----- NIL
#     * Rs.2,50,001-Rs.3,00,000----NIL
#     * Rs 3,00,001 -Rs 5,00,000----NIL
#     * Rs 5,00,001 to Rs 10,00,000----20%
#     * Rs 10,00,001 and above---30%
#
#
# 09:56:29 AM IST, 01 Feb 2025
#
# Union Budget 2025 Income Tax Live: Will FM Nirmala Sitharaman make further
# hikes in the long-term capital gains (LTCG) and STCG (short-term capital
# gains) rates in Union Budget 2025-26?
#
# Income Tax Union Budget 2025: Taxpayers are keeping their fingers crossed for
# no further hikes in capital gains taxation, especially for equity investments.
# Last Budget, FM Sitharaman had hiked the LTCG from 10% to 12.5%, minus the
# benefits of indexation. On the other hand, STCG was also hiked from 15% to
# 20%.
#
# Says Nikhil Behl, CEO - Stocks, INDmoney, "For the stock market, maintaining
# favorable tax conditions on equity investments will ensure consistent retail
# inflows, which are crucial for supporting market resilience during global
# uncertainties. It will also bolster long-term investor sentiment, ensuring
# steady participation in primary and secondary markets, which can drive
# economic growth and create value for investors across all segments.”
#
# 09:52:27 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Is a major income tax relief on the
# cards? Here is what PM Modi's words indicate
#
# Income Tax Budget 2025 Live Updates: In his address to the parliament
# yesterday, PM Modi invoked the blessings of Goddess Lakshmi, asking her to
# bless the poor and the middle class. Furthermore, President Draupadi Murmu
# also noted in her address that the economic growth of India is deeply linked
# to the aspirations of the middle class and their fulfillment. These words have
# spurred hope that some major income-tax reliefs for the taxpayers may be
# introduced by FM Sitharaman in her speech today.
#
# 09:46:02 AM IST, 01 Feb 2025
#
# Union Budget 2025 Income Tax Live: How much HRA can salaried employees claim
# under the old tax regime if they live in metro cities?
#
# India Budget 2025 Income Tax live Updates: Under Section 10(13A) of the Income
# Tax Act, employees living in rented accommodations in metro cities such as
# Delhi, Mumbai, Kolkata and Chennai. They can claim the lowest of the following
# amounts can be claimed as HRA exemption:
#
#
#     * Actual HRA received
#     * 50% of [basic salary + DA] for those living in metro cities (Delhi, Kolkata, Mumbai or Chennai)
#     * Actual rent paid (-) 10% of [basic salary + DA]
#
# 09:43:03 AM IST, 01 Feb 2025
#
# Union Budget 2025 Income Tax Live: Will Union Budget 2025-26 introduce an
# additional deduction of Rs 50,000 under 80CCD(1B) of the I-T Act for NPS?
#
# Budget 2025 Income Tax Live Updates: At present, the only NPS-related
# deduction allowed under the new tax regime is for the employer's contribution
# to employee NPS accounts (maximum deduction allowed of 14% of salary (basic +
# DA)). This is unlike in the old tax regime, which allows a tax break of up to
# Rs 50,000 on voluntary NPS contributions made by the employee to their NPS
# account, over and above the Rs 1.5 lakh limit offered under Section 80C.
#
# 09:42:54 AM IST, 01 Feb 2025
#
# Budget 2025 Income Tax Live Updates: What deductions/exemptions are available
# for interest paid on a home loan/principal repayment on a home loan under the
# old tax regime?
#
# Income Tax Union Budget 2025: Under Section 80EE, deduction towards interest
# payments made on loan taken for acquisition of residential house property If
# the loan is sanctioned between 1st April 2016 and 31st March 2017, a deduction
# limit of Rs 50,000 on the interest paid on loan taken is available.
#
# 09:35:03 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will Union Budget 2025-26 hike the tax-
# free limit for investments in NPS (National Pension System)?
#
# Income Tax Union Budget 2025: Experts are advocating that the tax-free limit
# for investments in the National Pension System (NPS) should be hiked from the
# present limit of Rs 50,000 to Rs. 1 lakh. Notably, this amount has been
# constant for the last 10 years. Even if it is inflation adjusted, the amount
# of deduction should be doubled. Also, withdrawal rules should be made more
# flexible so as to make withdrawal from the scheme totally tax-free on
# attaining senior citizen status, i.e., after turning 60.
#
# 09:31:24 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Can first-time taxpayers hope for some
# major tax reliefs from FM Sitharaman in this Union Budget 2025-26?
#
# Income Tax Union Budget 2025: The upcoming Union Budget 2025-26 should look to
# address some key challenges in the real estate sector. Says Siddharth S.
# Sharma, Vice President, Silverdome Realtors, "Increasing the tax deduction
# limit on home loan interest under Section 24(b) from Rs 2 lakhs to Rs 5 lakhs
# would ease the financial burden on homebuyers, particularly in the premium
# housing segment, and drive demand. Simplifying tax and investment regulations
# for NRIs, such as reducing TDS on property transactions and offering exclusive
# incentives, would attract more foreign capital, boosting the sector further."
#
# 09:21:44 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will FM Nirmala Sitharaman introduce
# deductions related to health insurance premiums in this Union Budget 2025-26?
#
# Income Tax Union Budget 2025: At present, under Section 80D of the Income Tax
# Act, the following deductions are offered to taxpayers opting for the old tax
# regime:
#
# For Self, Spouse or Dependent Children
#
#     * Rs 25,000 (Rs 50,000 if any person is a Senior Citizen)
#     * Rs 5,000 for preventive health check-ups, included in the above limit
#
# For Parents
#
#     * Rs 25,000 (Rs 50,000 if any person is a Senior Citizen)
#     * Rs 5,000 for preventive health check-ups, included in the above limit
#
# If No health insurance premium is paid/Medical Expenditure
#
#     * Self/Spouse: Deduction limit of Rs 50,000
#     * Parents: Deduction limit of Rs 50,000
#
# According to Rakesh Kumar, Founder Square Insurance, "In this upcoming budget,
# I believe the government will focus on reforms to make healthcare and
# insurance more accessible and affordable for everyone. Raising the tax
# exemption limit on health insurance premiums to Rs 75,000 and reducing GST
# from 18% to 5% could ease the financial burden on households and encourage
# more families to prioritize their health. Expanding the Ayushman Bharat scheme
# to include the middle class could also bridge significant gaps in healthcare
# coverage."
#
# 09:07:46 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Ahead of Union Budget 2025-26, what is
# the common man expecting from Union Budget 2025-26?
#
# Income Tax Union Budget 2025: As we inch closer to the Union Budget 2025-26
# presentation, here is a snapshot of all the major demands that taxpayers and
# middle-class Indians want from the upcoming budget 2025-26:
#
#
#     * Hike in standard deduction limit under old and new tax regimes
#     * Hike the basic exemption limit under the old and new tax regime
#     * Additional deduction of Rs 50,000 for investing in NPS under the new tax regime
#     * Additional deductions for home loan repayments under the new tax regime
#     * Easing administrative and compliance procedures related to income tax
#
# 08:59:44 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will Union Budget 2025-26 revisit the
# definition of affordable housing?
#
# India Budget 2025 Income Tax live Updates: Currently, affordable housing, for
# the purpose of PM Awas Yojana, is defined as a house having a carpet area of
# up to 60 sq m in metros and 90 sq m in non-metros. The value of the house
# should not exceed Rs 45 lakh. Experts are recommending increasing the upper
# property price limit from Rs 45 lakhs to Rs 75 lakhs in metro cities and
# raising the carpet area threshold to 90 sq. m in metro cities.
#
# 08:37:30 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: What are the currently applicable income
# tax slabs under the old regime for senior citizens, i.e. those aged between 60
# and 80 years?
#
# The old tax regime currently has the following income tax slabs for senior
# citizens, i.e., individuals who are above 60 but less than 80 years of age or
# are not super senior citizens:
#
#
#     * Up to Rs 2,50,000--NIL
#     * Rs.2,50,001-Rs.3,00,000-- NIL
#     * Rs 3,00,001-Rs 5,00,000--5%
#     * Rs 5,00,001 to Rs 10,00,000--20%
#     * Rs 10,00,001 and above--30%
#
#
# 08:33:17 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will FM Nirmala Sitharaman give Ayushman
# Bharat Yojana a shot in the arm during Budget 2025-26?
#
# India Budget 2025 Income Tax live Updates: According to the Economic Survey
# released yesterday, the Ayushman Bharat scheme presently covers over 40% of
# the most vulnerable populations, thereby covering approximately 55 crore
# people. AB PM-JAY provides cashless cover of up to Rs 5,00,000/- to each
# eligible family per annum. Note that this cover is offered on a floater basis,
# i.e., the coverage is shared by all members of a single family. The scheme
# covers the following treatments:
#
#
#     * Medical examination, treatment, and consultation
#     * Pre-hospitalization
#     * Medicine and medical consumables
#     * Diagnostic and laboratory investigations
#     * Accommodation benefits
#     * Complications arising during treatment
#     * Post-hospitalization follow-up care up to 15 days
#
#
# 08:23:23 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will FM Nirmala Sitharaman make first-
# time home owners happy in this Union Budget 2025-26?
#
# India Budget 2025 Income Tax live Updates: At present, those looking to buy a
# house have minimal benefits under the new tax regime. The old tax regime, on
# the other hand, offers multiple benefits to first-time home owners and those
# looking to buy a house. These include deduction of interest on housing loans
# to the extent of Rs 2 lakh per annum, and more.
#
# Says Sanjay Dutt, MD and CEO, Tata Realty and Infrastructure Ltd, "We are
# expecting a higher deduction for housing loan principal repayment, increasing
# the limit from Rs 150,000 to Rs 500,000 under Section 80C, and raising the tax
# deduction on interest paid for let-out properties from Rs 2 lakh to Rs 4-5
# lakh. Revival of the Credit Linked Subsidy Scheme (CLSS) for first-time
# homebuyers and reintroduction of tax holidays under Section 80IBA for
# affordable housing projects would provide significant support to financially
# weaker buyers."
#
# 08:09:27 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will FM Nirmala Sitharaman merge the old
# and new tax regimes in this Union Budget 2025-26?
#
#
# Income Tax Budget 2025 Live Updates: The Budget announced in July 2024 brought
# limited changes for individual taxpayers, leaving many to hope that the
# upcoming Budget 2025 will deliver the much-needed tax relief to alleviate
# their financial pressures. There is a strong expectation that the government
# will focus on improving taxpayers' savings by introducing reforms such as a
# unified tax regime and enhanced deductions.
#
# According to Deepashree Shetty, Partner, Global Employer Services, Tax &
# Regulatory Services, BDO India, "The introduction of two tax regimes—the Old
# Tax Regime (OTR) and New Tax Regime (NTR)—was intended to offer taxpayers
# flexibility, allowing them to choose the system that best suits their
# investments, savings habits, and preferences. However, the reality has been
# far more complex. Many taxpayers find themselves confused between the two
# regimes, often reassessing their choice not only during the year but also
# while filing their tax returns. In light of these complexities, the upcoming
# budget should focus on simplifying the tax structure for individual taxpayers
# by consolidating the current dual regimes into a single, cohesive tax
# framework. "
#
#
# 08:05:00 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: What is in store for senior citizens in
# the Union Budget 2025-26?
#
# Budget 2025 Income Tax Live Updates: As of 2025, the average life expectancy
# in India is approximately 71 years, up from 68 years a decade ago. As such,
# there needs to be some efforts to secure the financial well-being of our
# elderly population. As per
# Meera Laetitia B. Aranha, Professor, Accounting, Economics, and Finance Area,
# T A Pai Management Institute (TAPMI), suggests the government could introduce
# the following measures to alleviate the financial stress of senior citizens:
#
#
#     * Tax-Free Interest Income: Most of the citizens live out of their returns on their savings or interest earned on fixed deposits. These savings are net of tax, which they have paid earlier. Therefore, make returns on savings tax-free to adjust for inflation.
#
#
#     * Health Insurance Deductions: People rely on medical health insurance to help them settle their medical bills. Allow full deductions for health insurance premiums and medical treatment costs for specified diseases like cancer.
#
#
#     * Simplified Procedures: Streamline application and claim processes for tax benefits. and schemes to reduce administrative burdens and make them more accessible for senior citizens.
#
#
# ![Income Tax Budget 2025 Live Updates: What is in store for senior citizens in
# the Union Budget
# 2025-26?](https://img.etimg.com/thumb/msid-117810904,width-445,resizemode-4/income-
# tax-budget-2025-live-updates-what-is-in-store-for-senior-citizens-in-the-
# union-budget-2025-26.jpg)
#
# 08:00:00 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Will Union Budget 2025-26 introduce an
# additional deduction of Rs 50,000 under 80CCD(1B) of the I-T Act for NPS?
#
# Budget 2025 Income Tax Live Updates: At present, the only NPS-related
# deduction allowed under the new tax regime is for the employer's contribution
# to employee NPS accounts (maximum deduction allowed of 14% of salary (basic +
# DA)). This is unlike in the old tax regime, which allows a tax break of up to
# Rs 50,000 on voluntary NPS contributions made by the employee to their NPS
# account, over and above the Rs 1.5 lakh limit offered under Section 80C.
#
# Experts are hopeful that a similar deduction will be allowed under the new tax
# regime as well in the Union Budget 2025-26
#
# ![Income Tax Budget 2025 Live Updates: Will Union Budget 2025-26 introduce an
# additional deduction of Rs 50,000 under 80CCD\(1B\) of the I-T Act for
# NPS?](https://img.etimg.com/thumb/msid-117810762,width-445,resizemode-4/income-
# tax-budget-2025-live-updates-will-union-budget-2025-26-introduce-an-
# additional-deduction-of-rs-50000-under-80ccd1b-of-the-i-t-act-for-nps.jpg)
#
# 07:52:54 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: What are some of the key deductions
# available under Section 80C of the Income Tax Act?
#
# Budget 2025 Income Tax Live Updates: Section 80C of the Income Tax Act offers
# a comprehensive deduction limit of Rs. 1,50,000 for various investment and
# insurance-related purposes. Some of these include:
#
#
#     * Life Insurance Premium
#     * Provident Fund+ ELSS
#     * National Savings Certificate
#     * Housing Loan Principal
#     * Contributions to PPF (Public Provident Fund) or NPS (National Pension Scheme)
#     * Annuity plan of LIC or other insurer towards Pension Scheme
#
# 07:42:40 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: What deductions/exemptions are available
# for health insurance premium payments in the old tax regime?
#
# Budget 2025 Income Tax Live Updates: Currently, in the old tax regime,
# taxpayers can opt for the following deductions on medical expenses and health
# insurance premiums paid, under Section 80D of the Income Tax Act.
#
# For Self / Spouse or Dependent Children
#
#     * Rs 25,000 (Rs 50,000 if any person is a Senior Citizen)
#     * Rs 5,000 for preventive health check-ups, included in the above limit
#
# For Parents
#
#     * Rs 25,000 (Rs 50,000 if any person is a Senior Citizen)
#     * Rs 5,000 for preventive health check-ups, included in the above limit
#
# If No health insurance premium is paid/deduction available for medical
# expenditure made during the year
#
#     * Self/Spouse: Deduction limit of Rs 50,000
#     * Parents: Deduction limit of Rs 50,000
#
# 07:28:04 AM IST, 01 Feb 2025
#
# Income Tax Budget 2025 Live Updates: Can taxpayers expect a hike in the home-
# loan interest deduction limit of Rs 2,00,000 in the old regime?
#
# Budget 2025 Income Tax Live Updates: Currently, section 24(b) of the IT Act
# provides for a deduction of Rs. 2,00,000 from the Net Annual Value (NAV) of
# house property in respect of payment of interest on loan obtained for the
# ...
# price](https://economictimes.indiatimes.com/bharat-heavy-electricals-
# ltd/stocks/companyid-11831.cms "BHEL share price")[Infosys share
# price](https://economictimes.indiatimes.com/infosys-
# ltd/stocks/companyid-10960.cms "Infosys share price")[IRCTC share
# price](https://economictimes.indiatimes.com/indian-railway-catering-tourism-
# corporation-ltd/stocks/companyid-16705.cms "IRCTC share price")[ITC share
# price](https://economictimes.indiatimes.com/itc-ltd/stocks/companyid-13554.cms
# "ITC share price")[JIO finance share
# price](https://economictimes.indiatimes.com/jio-financial-services-
# ltd/stocks/companyid-14555.cms "JIO finance share price")[LIC share
# price](https://economictimes.indiatimes.com/life-insurance-corporation-of-
# india/stocks/companyid-5050.cms "LIC share price")[Reliance share
# price](https://economictimes.indiatimes.com/reliance-industries-
# ltd/stocks/companyid-13215.cms "Reliance share price")[HAL share
# price](https://economictimes.indiatimes.com/hindustan-aeronautics-
# ltd/stocks/companyid-9206.cms "HAL share price")[JP Power share
# price](https://economictimes.indiatimes.com/jaiprakash-power-ventures-
# ltd/stocks/companyid-1513.cms "JP Power share price")[NBCC share
# price](https://economictimes.indiatimes.com/nbcc-india-
# ltd/stocks/companyid-4531.cms "NBCC share price")[TCS share
# price](https://economictimes.indiatimes.com/tata-consultancy-services-
# ltd/stocks/companyid-8345.cms "TCS share price")[Vedanta share
# price](https://economictimes.indiatimes.com/vedanta-
# ltd/stocks/companyid-13111.cms "Vedanta share price")[Wipro share
# price](https://economictimes.indiatimes.com/wipro-
# ltd/stocks/companyid-12799.cms "Wipro share price")[IOC share
# price](https://economictimes.indiatimes.com/indian-oil-corporation-
# ltd/stocks/companyid-11924.cms "IOC share price")[Ircon share
# price](https://economictimes.indiatimes.com/ircon-international-
# ltd/stocks/companyid-11980.cms "Ircon share price")[SAIL share
# price](https://economictimes.indiatimes.com/steel-authority-of-india-sail-
# ltd/stocks/companyid-11974.cms "SAIL share price")[SJVN share
# price](https://economictimes.indiatimes.com/sjvn-
# ltd/stocks/companyid-18460.cms "SJVN share price")[GAIL share
# price](https://economictimes.indiatimes.com/gail-india-
# ltd/stocks/companyid-4845.cms "GAIL share price")[HUDCO share
# price](https://economictimes.indiatimes.com/housing-and-urban-development-
# corporation-ltd/stocks/companyid-4516.cms "HUDCO share price")[REC share
# price](https://economictimes.indiatimes.com/rec-ltd/stocks/companyid-4616.cms
# "REC share price")[Reliance Power share
# price](https://economictimes.indiatimes.com/reliance-power-
# ltd/stocks/companyid-4422.cms "Reliance Power share price")[Tata Technologies
# share price](https://economictimes.indiatimes.com/tata-technologies-
# ltd/stocks/companyid-4612.cms "Tata Technologies share price")[Vodafone idea
# share price](https://economictimes.indiatimes.com/vodafone-idea-
# ltd/stocks/companyid-3154.cms "Vodafone idea share price")[Adani Enterprises
# share price](https://economictimes.indiatimes.com/adani-enterprises-
# ltd/stocks/companyid-9074.cms "Adani Enterprises share price")[Adani Green
# share price](https://economictimes.indiatimes.com/adani-green-energy-
# ltd/stocks/companyid-64847.cms "Adani Green share price")[Adani Port share
# price](https://economictimes.indiatimes.com/adani-ports-special-economic-zone-
# ltd/stocks/companyid-20316.cms "Adani Port share price")[Ashok Leyland share
# price](https://economictimes.indiatimes.com/ashok-leyland-
# ltd/stocks/companyid-14041.cms "Ashok Leyland share price")[Bank of Baroda
# share price](https://economictimes.indiatimes.com/bank-of-
# baroda/stocks/companyid-12040.cms "Bank of Baroda share price")[BSE share
# price](https://economictimes.indiatimes.com/bse-ltd/stocks/companyid-2809.cms
# "BSE share price")[Canara Bank share
# price](https://economictimes.indiatimes.com/canara-
# bank/stocks/companyid-9218.cms "Canara Bank share price")[CDSL share
# price](https://economictimes.indiatimes.com/central-depository-services-india-
# ltd/stocks/companyid-4259.cms "CDSL share price")[Coal India share
# price](https://economictimes.indiatimes.com/coal-india-
# ltd/stocks/companyid-11822.cms "Coal India share price")[HFCL share
# price](https://economictimes.indiatimes.com/hfcl-
# ltd/stocks/companyid-13649.cms "HFCL share price")[IDFC First Bank share
# price](https://economictimes.indiatimes.com/idfc-first-bank-
# ltd/stocks/companyid-62245.cms "IDFC First Bank share price")
#
# Top Calculators
#
# MORE
#
# [Standard Deviation
# Calculator](https://economictimes.indiatimes.com/news/standard-deviation-
# variance-calculator "Standard Deviation Calculator")[Income Tax
# Calculator](https://economictimes.indiatimes.com/wealth/calculators/income-
# tax-calculator "Income Tax Calculator")[Age
# Calculator](https://economictimes.indiatimes.com/news/age-calculator "Age
# Calculator")[SIP
# Calculator](https://economictimes.indiatimes.com/wealth/calculators/sip-
# calculator "SIP Calculator")[Time
# Calculator](https://economictimes.indiatimes.com/news/time-calculator "Time
# Calculator")[BMI
# Calculator](https://economictimes.indiatimes.com/magazines/panache/bmi-
# calculator "BMI Calculator")[GPA
# Calculator](https://economictimes.indiatimes.com/news/gpa-calculator "GPA
# Calculator")[Statistics
# Calculator](https://economictimes.indiatimes.com/news/statistics-calculator
# "Statistics Calculator")[Fraction
# Calculator](https://economictimes.indiatimes.com/news/fraction-calculator
# "Fraction Calculator")[Diabetes Risk
# Calculator](https://economictimes.indiatimes.com/magazines/panache/diabetes-
# risk-calculator "Diabetes Risk Calculator")[Date
# Calculator](https://economictimes.indiatimes.com/news/date-calculator "Date
# Calculator")[Log Calculator](https://economictimes.indiatimes.com/news/log-
# calculator "Log Calculator")
#
# Latest News
#
# [Union Budget 2025: Important tech and startup
# announcements](https://economictimes.indiatimes.com/tech/startups/union-
# budget-2025-important-tech-and-startup-
# announcements/articleshow/117821593.cms)[Union Budget 2025: Boosting
# innovation, exports, & global trade with strategic
# initiatives](https://economictimes.indiatimes.com/news/economy/policy/union-
# budget-2025-boosting-innovation-exports-global-trade-with-strategic-
# initiatives/articleshow/117821794.cms)[WeWork India and WeWork Inc to divest
# around 25% stake through
# IPO](https://economictimes.indiatimes.com/markets/stocks/news/wework-india-
# and-wework-inc-to-divest-around-25-stake-through-
# ipo/articleshow/117821760.cms)[MSMEs get Budget push: Boosting exports,
# improving credit access, creating women
# entrepreneurs](https://economictimes.indiatimes.com/news/economy/policy/msmes-
# get-budget-push-boosting-exports-improving-credit-access-creating-women-
# entrepreneurs/articleshow/117821510.cms)[Budget 2025 full speech: Read FM
# Nirmala Sitharaman's Union Budget address
# here](https://economictimes.indiatimes.com/news/economy/policy/budget-2025-full-
# speech-read-fm-nirmala-sitharamans-union-budget-address-
# here/articleshow/117821002.cms)[Budget 2025: Heavyweight consumer stocks ITC,
# HUL surge over 5% after FM announces tax
# bonanza](https://economictimes.indiatimes.com/markets/stocks/news/budget-2025-heavyweight-
# consumer-stocks-itc-hul-surge-over-5-after-fm-announces-tax-
# bonanza/articleshow/117821657.cms)[Union Budget 2025: Indian shipping gets a
# budget
# bonanza](https://economictimes.indiatimes.com/industry/transportation/shipping-/-transport/union-
# budget-2025-indian-shipping-gets-a-budget-
# bonanza/articleshow/117821442.cms)[Union Budget 2025: Key announcements for
# AI, startups](https://economictimes.indiatimes.com/tech/startups/union-
# budget-2025-key-announcements-for-ai-startups/articleshow/117820898.cms)[Govt
# to rationalise TDS to ease compliance burden, says
# Sitharaman](https://economictimes.indiatimes.com/news/economy/policy/govt-to-
# rationalise-tds-to-ease-compliance-burden-says-
# sitharaman/articleshow/117821395.cms)[Budget 2025: Government extends Udan
# scheme by 10
# years](https://economictimes.indiatimes.com/industry/transportation/airlines-/-aviation/budget-2025-government-
# extends-udan-scheme-by-10-years/articleshow/117821357.cms)[Union Budget 2025:
# FM announces export promotion mission to facilitate easier access to export
# credit](https://economictimes.indiatimes.com/small-
# biz/trade/exports/insights/union-budget-2025-fm-announces-export-promotion-
# mission-to-facilitate-easier-access-to-export-
# credit/articleshow/117821341.cms)[Govt to rationalise TDS to ease compliance
# burden, says
# Sitharaman](https://economictimes.indiatimes.com/tech/startups/govt-to-
# rationalise-tds-to-ease-compliance-burden-says-
# sitharaman/articleshow/117821275.cms)[Union Budget 2025: 50,000 Atal Tinkering
# Labs will be set up in next five years:
# FM](https://economictimes.indiatimes.com/tech/technology/union-
# budget-2025-50000-atal-tinkering-labs-will-be-set-up-in-next-five-years-
# fm/articleshow/117821179.cms)[Has Section 80C deduction limit hiked? Check how
# much tax you can save after Union Budget
# 2025](https://economictimes.indiatimes.com/wealth/tax/has-
# section-80c-deduction-limit-hiked-check-how-much-you-can-save-after-union-
# budget-2025/articleshow/117821055.cms)[Union Budget 2025: Govt committed to
# ensuring regulations keep pace with global technological advancements, says
# Sitharaman](https://economictimes.indiatimes.com/small-biz/sme-sector/union-
# budget-2025-govt-committed-to-ensuring-regulations-keep-pace-with-global-
# technological-advancements-says-sitharaman/articleshow/117820850.cms)
#
# Follow us on:
#
# [](https://www.facebook.com/EconomicTimes
# "Facebook")[](https://twitter.com/economictimes
# "Twitter")[](https://www.linkedin.com/company/economictimes
# "LinkedIn")[](https://economictimes.indiatimes.com/rss.cms "RSS")
#
# ## Download ET App:
#
# [](https://play.google.com/store/apps/details?id=com.et.reader.activities)[](https://itunes.apple.com/us/app/the-
# economic-times/id474766725?ls=1&t=8apple.com/us)
#
# [](https://economictimes.indiatimes.com/prime?utm_source=economictimes.indiatimes.com&utm_medium=footer&utm_campaign=ETPrimedistribution)
#
# [subscribe to our
# newsletter](https://economictimes.indiatimes.com/subscription)
#
# Copyright (C) 2025 Bennett, Coleman & Co. Ltd. All rights reserved. For
# reprint rights: [Times Syndication
# Service](https://timescontent.timesgroup.com/)
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 39.440000 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 1.877860 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# ERROR:asyncio:Exception in callback Dispatcher.span.<locals>.wrapper.<locals>.handle_future_result(span_id='Workflow.run...-0eebb1546158', bound_args=<BoundArgumen...mory': None})>, instance=<llama_index....x7dc1e8717710>, context=<_contextvars...x7dc1e8925e40>)(<WorkflowHand...exceeded'}}")>) at /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py:273
# handle: <Handle Dispatcher.span.<locals>.wrapper.<locals>.handle_future_result(span_id='Workflow.run...-0eebb1546158', bound_args=<BoundArgumen...mory': None})>, instance=<llama_index....x7dc1e8717710>, context=<_contextvars...x7dc1e8925e40>)(<WorkflowHand...exceeded'}}")>) at /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py:273>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py", line 247, in _task
#     new_ev = await instrumented_step(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 367, in async_wrapper
#     result = await func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/agent/workflow/multi_agent_workflow.py", line 290, in run_agent_step
#     agent_output = await agent.take_step(
#                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/agent/workflow/react_agent.py", line 93, in take_step
#     async for r in response:
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/llms/callbacks.py", line 88, in wrapped_gen
#     async for x in f_return_val:
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/llms/openai/base.py", line 724, in gen
#     async for response in await aclient.chat.completions.create(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/resources/chat/completions.py", line 1720, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1849, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1543, in request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1629, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1676, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1629, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1676, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1629, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1676, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/openai/_base_client.py", line 1644, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-XqxsrErw5IF0yK8HMOvuryK2 on tokens per min (TPM): Limit 60000, Used 57925, Requested 49987. Please try again in 47.912s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 285, in handle_future_result
#     raise exception
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py", line 445, in _run_workflow
#     raise exception_raised
#   File "/usr/local/lib/python3.11/dist-packages/llama_index/core/workflow/workflow.py", line 254, in _task
#     raise WorkflowRuntimeError(
# llama_index.core.workflow.errors.WorkflowRuntimeError: Error in step 'run_agent_step': Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-XqxsrErw5IF0yK8HMOvuryK2 on tokens per min (TPM): Limit 60000, Used 57925, Requested 49987. Please try again in 47.912s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
